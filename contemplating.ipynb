# %% [markdown]
# # 철학적으로 느껴지는, 인생에 대해 새로운 통찰을 주는 것 같은, 생각 속으로 침잠해 가는 듯한, 질문을 던지는 듯한 곡

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from pydub import AudioSegment
import librosa.display
import sklearn
import csv
hop_length=200

# %%
"""
sound = AudioSegment.from_mp3("aftermath.mp3")
sound.export("aftermath.wav", format="wav")
sound = AudioSegment.from_mp3("angel.mp3")
sound.export("angel.wav", format="wav")
sound = AudioSegment.from_mp3("athousandmiles.mp3")
sound.export("athousandmiles.wav", format="wav")
sound = AudioSegment.from_mp3("cantyousee.mp3")
sound.export("cantyousee.wav", format="wav")
sound = AudioSegment.from_mp3("doingallright.mp3")
sound.export("doingallright.wav", format="wav")
sound = AudioSegment.from_mp3("freedom90.mp3")
sound.export("freedom90.wav", format="wav")
sound = AudioSegment.from_mp3("goodbyetown.mp3")
sound.export("goodbyetown.wav", format="wav")
sound = AudioSegment.from_mp3("highanddry.mp3")
sound.export("highanddry.wav", format="wav")
sound = AudioSegment.from_mp3("hymnofthebirds.mp3")
sound.export("hymnofthebirds.wav", format="wav")
sound = AudioSegment.from_mp3("iruntoyou.mp3")
sound.export("iruntoyou.wav", format="wav")
sound = AudioSegment.from_mp3("mytime.mp3")
sound.export("mytime.wav", format="wav")
sound = AudioSegment.from_mp3("needyounow.mp3")
sound.export("needyounow.wav", format="wav")
sound = AudioSegment.from_mp3("ourkindoflove.mp3")
sound.export("ourkindoflove.wav", format="wav")
sound = AudioSegment.from_mp3("outlawsoflove.mp3")
sound.export("outlawsoflove.wav", format="wav")
sound = AudioSegment.from_mp3("ppcx.mp3")
sound.export("ppcx.wav", format="wav")
sound = AudioSegment.from_mp3("readytoloveagain.mp3")
sound.export("readytoloveagain.wav", format="wav")
sound = AudioSegment.from_mp3("road.mp3")
sound.export("road.wav", format="wav")
sound = AudioSegment.from_mp3("underpressure.mp3")
sound.export("underpressure.wav", format="wav")
sound = AudioSegment.from_mp3("walkingthewire.mp3")
sound.export("walkingthewire.wav", format="wav")
sound = AudioSegment.from_mp3("whataboutus.mp3")
sound.export("whataboutus.wav", format="wav")
sound = AudioSegment.from_mp3("wrecksyou.mp3")
sound.export("wrecksyou.wav", format="wav")
sound = AudioSegment.from_mp3("flashdance.mp3")
sound.export("flashdance.wav", format="wav")
sound = AudioSegment.from_mp3("puberty.mp3")
sound.export("puberty.wav", format="wav")
sound = AudioSegment.from_mp3("rose.mp3")
sound.export("rose.wav", format="wav")
sound = AudioSegment.from_mp3("sea.mp3")
sound.export("sea.wav", format="wav")
sound = AudioSegment.from_mp3("stay.mp3")
sound.export("stay.wav", format="wav")
sound = AudioSegment.from_mp3("miles2.mp3")
sound.export("miles2.wav", format="wav")
sound = AudioSegment.from_mp3("story.mp3")
sound.export("story.wav", format="wav")
sound = AudioSegment.from_mp3("visitors.mp3")
sound.export("visitors.wav", format="wav")
"""
# Out:
# '\nsound = AudioSegment.from_mp3("aftermath.mp3")\nsound.export("aftermath.wav", format="wav")\nsound = AudioSegment.from_mp3("angel.mp3")\nsound.export("angel.wav", format="wav")\nsound = AudioSegment.from_mp3("athousandmiles.mp3")\nsound.export("athousandmiles.wav", format="wav")\nsound = AudioSegment.from_mp3("cantyousee.mp3")\nsound.export("cantyousee.wav", format="wav")\nsound = AudioSegment.from_mp3("doingallright.mp3")\nsound.export("doingallright.wav", format="wav")\nsound = AudioSegment.from_mp3("freedom90.mp3")\nsound.export("freedom90.wav", format="wav")\nsound = AudioSegment.from_mp3("goodbyetown.mp3")\nsound.export("goodbyetown.wav", format="wav")\nsound = AudioSegment.from_mp3("highanddry.mp3")\nsound.export("highanddry.wav", format="wav")\nsound = AudioSegment.from_mp3("hymnofthebirds.mp3")\nsound.export("hymnofthebirds.wav", format="wav")\nsound = AudioSegment.from_mp3("iruntoyou.mp3")\nsound.export("iruntoyou.wav", format="wav")\nsound = AudioSegment.from_mp3("mytime
# ...

# %%
tf, sr = librosa.load('34.wav', sr=44100, offset=0.49, duration=22.611) # 23.101
am, sr = librosa.load('aftermath.wav', sr=44100, offset=0.149, duration=12.683) # 12.832
angel1, sr = librosa.load('angel.wav', sr=44100, offset=10.762, duration=12.448) # 23.21
angel2, sr = librosa.load('angel.wav', sr=44100, offset=61.647, duration=11.211) # 72.858
dambi, sr = librosa.load('cantyousee.wav', sr=44100, offset=0.608, duration=5.269)
fine1, sr = librosa.load('fine.wav', sr=44100, offset=1.71, duration=6.677) # 8.387
fine2, sr = librosa.load('fine.wav', sr=44100, offset=8.387, duration=21.152) # 29.539
fine3, sr = librosa.load('fine.wav', sr=44100, offset=52.081, duration=21.066) # 73.147
waf, sr = librosa.load('flashdance.wav', sr=44100, offset=0.266, duration=9.958)
free1, sr = librosa.load('freedom90.wav', sr=44100, offset=0.32, duration=35.413) # 35.733
free2, sr = librosa.load('freedom90.wav', sr=44100, offset=36.428, duration=19.206) # 55.634
gbt1, sr = librosa.load('goodbyetown.wav', sr=44100, offset=0.437, duration=10.998)
gbt2, sr = librosa.load('goodbyetown.wav', sr=44100, offset=11.435, duration=19.023) # 30.458
had1, sr = librosa.load('highanddry.wav', sr=44100, offset=0.48, duration=15.552) #
had2, sr = librosa.load('highanddry.wav', sr=44100, offset=38.943, duration=21.632) #60.575
had3, sr = librosa.load('highanddry.wav', sr=44100, offset=69.567, duration=11.2) #80.767
home1, sr = librosa.load('home.wav', sr=44100, offset=0.618, duration=9.888)
home2, sr = librosa.load('home.wav', sr=44100, offset=10.3, duration=22.624) # 32.924
home3, sr = librosa.load('home.wav', sr=44100, offset=54, duration=25.389) #79.389
home4, sr = librosa.load('home.wav', sr=44100, offset=164.336, duration=8.875) #173.211
hymn1, sr = librosa.load('hymn.wav', sr=44100, offset=0.277, duration=16.557) # 16.834
hymn2, sr = librosa.load('hymn.wav', sr=44100, offset=31.43, duration=13.07) # 44.5
hymn3, sr = librosa.load('hymn.wav', sr=44100, offset=83.464, duration=6.864) # 90.328
hymn4, sr = librosa.load('hymn.wav', sr=44100, offset=70.12, duration=13.025) # 83.145
irty1, sr = librosa.load('iruntoyou.wav', sr=44100, offset=0.224, duration=8.458) # 8.682
irty2, sr = librosa.load('iruntoyou.wav', sr=44100, offset=16.212, duration=34.011) # 50.223
#irty3, sr = librosa.load('iruntoyou.wav', sr=44100, offset=67.707, duration=) #
mir1, sr = librosa.load('makeitright.wav', sr=44100, offset=0.458, duration=8.918) # 9.376
mir2, sr = librosa.load('makeitright.wav', sr=44100, offset=9.667, duration=17.879) # 27.546
mir3, sr = librosa.load('makeitright.wav', sr=44100, offset=28.762, duration=7.808) # 36.57
mir4, sr = librosa.load('makeitright.wav', sr=44100, offset=46.73, duration=14.862) # 61.592
miles1, sr = librosa.load('miles1.wav', sr=44100, offset=0.128, duration=9.888) # 10.016
miles2, sr = librosa.load('miles1.wav', sr=44100, offset=10.016, duration=10.557) # 20.573
miles3, sr = librosa.load('miles1.wav', sr=44100, offset=30.816, duration=9.44) # 40.256
time1, sr = librosa.load('mytime.wav', sr=44100, offset=0.234, duration=18.411) # 18.645
time2, sr = librosa.load('mytime.wav', sr=44100, offset=95.622, duration=18.902) # 114.524
time3, sr = librosa.load('mytime.wav', sr=44100, offset=19.218, duration=17.892) # 37.11 
time4, sr = librosa.load('mytime.wav', sr=44100, offset=38.043, duration=14.197) # 52.24
nyn1, sr = librosa.load('needyounow.wav', sr=44100, offset=9.993, duration=8.808) # 18.801
nyn2, sr = librosa.load('needyounow.wav', sr=44100, offset=35.481, duration=13.644) # 49.125
nyn3, sr = librosa.load('needyounow.wav', sr=44100, offset=58.505, duration=13.644) # 74.562
ol, sr = librosa.load('onelove.wav', sr=44100, offset=7.278, duration=8.918) # 18.388
ool, sr = librosa.load('outlawsoflove.wav', sr=44100, offset=0.192, duration=25.002) # 25.194
polo, sr = librosa.load('polo.wav', sr=44100, offset=0.789, duration=2.464) # 3.253
ppcx1, sr = librosa.load('ppcx.wav', sr=44100, offset=0.486, duration=16.58) # 17.066
ppcx2, sr = librosa.load('ppcx.wav', sr=44100, offset=76.036, duration=18.586) # 94.622
pub1, sr = librosa.load('puberty.wav', sr=44100, offset=8.125, duration=17.696) # 25.821
pub2, sr = librosa.load('puberty.wav', sr=44100, offset=44.023, duration=13.899) # 57.922
pub3, sr = librosa.load('puberty.wav', sr=44100, offset=177.039, duration=5.269) # 182.308
rtla1, sr = librosa.load('readytoloveagain.wav', sr=44100, offset=0.266, duration=4.558) # 4.824
rtla2, sr = librosa.load('readytoloveagain.wav', sr=44100, offset=14.45, duration=14.098) # 28.548
rose1, sr = librosa.load('rose.wav', sr=44100, offset=0.277, duration=5.419) # 5.696
rose2, sr = librosa.load('rose.wav', sr=44100, offset=15.646, duration=15.449) # 31.145
rose3, sr = librosa.load('rose.wav', sr=44100, offset=61.739, duration=10.041) # 71.78
sea, sr = librosa.load('sea.wav', sr=44100, offset=11.696, duration=11.146) # 22.842
stay, sr = librosa.load('stay2.wav', sr=44100, offset=2.874, duration=10.203) # 13.077
story, sr = librosa.load('story.wav', sr=44100, offset=0.181, duration=7.889) # 8.07
#abba, sr = librosa.load('visitors.wav', sr=44100, offset=, duration=) # 
wtw1, sr = librosa.load('walkingthewire.wav', sr=44100, offset=23.415, duration=4.803) # 28.218
wtw2, sr = librosa.load('walkingthewire.wav', sr=44100, offset=50.952, duration=9.546) # 60.498
wtw3, sr = librosa.load('walkingthewire.wav', sr=44100, offset=127.882, duration=11.257) # 139.157
wal1, sr = librosa.load('wealllie.wav', sr=44100, offset=0.725, duration=9.653) # 10.378
wal2, sr = librosa.load('wealllie.wav', sr=44100, offset=30.791, duration=10.296) # 41.087
wal3, sr = librosa.load('wealllie.wav', sr=44100, offset=51.551, duration=9.909) # 61.46
wau1, sr = librosa.load('whataboutus.wav', sr=44100, duration=8.38)
wau2, sr = librosa.load('whataboutus.wav', sr=44100, offset=8.38, duration=7.95) #16.33
wreck1, sr = librosa.load('wrecksyou.wav', sr=44100, offset=9.561, duration=14.2) # 
wreck2, sr = librosa.load('wrecksyou.wav', sr=44100, offset=190.322, duration=13.44) # 203.762
wreck3, sr = librosa.load('wrecksyou.wav', sr=44100, offset=209.636, duration=18.382) # 228.018

# %%
def vector_split(v, n_split):
    v=np.array(v)
    length=len(v)//n_split
    res=[]
    for i in range(n_split-1):
        res.append(v[i*length:(i+1)*length])
    res.append(v[(i+1)*length:])
    return np.array(res)

def split_mean(v, n_split):
    splitted_vector=vector_split(v, n_split)
    res=[]
    for i in splitted_vector:
        res.append(i.mean())
    return np.array(res)

def mfccs(songname):
    """
    mfccs = librosa.feature.mfcc(songname, sr=44100, n_mfcc=10)
    mfccs = sklearn.preprocessing.scale(mfccs, axis=1)
    librosa.display.specshow(mfccs, sr=sr, x_axis='time')
    """
    mfccs = librosa.feature.mfcc(songname, sr=44100, n_mfcc=20)
    mfccs = split_mean(mfccs, 10)
    return list(mfccs)

def normalize(x, axis=0):
    return sklearn.preprocessing.minmax_scale(x, axis=axis)

def centroid(songname):
    song_sc = normalize(librosa.feature.spectral_centroid(songname,sr=sr)[0])
    #frames = range(len(song_sc))
    #t = librosa.frames_to_time(frames)
    song_sc_data = split_mean(song_sc,10)
    return list(song_sc_data)
    """
    # normalize for visualization purposes
    librosa.display.waveplot(songname,sr=sr,alpha=0.4)
    plt.plot(t,song_sc,color='r')
    """

def mel(songname):
    name_stft = np.abs(librosa.stft(songname))
    name_mel = librosa.feature.melspectrogram(S=name_stft**2)
    """
    librosa.display.specshow(librosa.amplitude_to_db(name_mel), x_axis='time', y_axis='log')
    plt.colorbar()
    """
    new = librosa.amplitude_to_db(name_mel)
    new = split_mean(new, 10)
    return list(new)

def contrast(songname):
    name_cont = librosa.feature.spectral_contrast(songname, sr=sr)
    #plt.imshow(normalize(name_cont, axis=1), aspect='auto', origin='lower', cmap='coolwarm')
    name_cont_data = split_mean(name_cont,7)
    return list(name_cont_data)
"""
def novelty(songname):
    name_onset_env = librosa.onset.onset_strength(songname, sr=sr, hop_length=200, n_fft=2048)
    # Plot the onset envelope
    frames = range(len(name_onset_env))
    name_t = librosa.frames_to_time(frames, sr=sr, hop_length=200)
    plt.plot(name_t, name_onset_env)
    plt.xlim(0, name_t.max())
    plt.ylim(0)
    plt.xlabel('Time (sec)')
    plt.title('Novelty Function')
    return name_onset_env
"""

def tempogram(songname):
    onset_env = librosa.onset.onset_strength(songname, sr=sr, hop_length=200, n_fft=2048)
    name_S = librosa.stft(onset_env, hop_length=1, n_fft=512)
    name_fourier_tempogram = np.absolute(name_S)
    # librosa.display.specshow(name_fourier_tempogram, sr=sr, hop_length=hop_length, x_axis='time')
    name_ft_data = split_mean(name_fourier_tempogram,10)
    return list(name_ft_data)


def writefile(songlist):
    with open("contemplating.csv", 'w', newline='') as f:
        w = csv.writer(f)
        for song in songlist:
            temp = ['contemplating']
            temp.extend(mfccs(song))
            temp.extend(mel(song))
            temp.extend(centroid(song))
            temp.extend(contrast(song))
            temp.extend(tempogram(song))
            w.writerow(temp)


songlist = [tf,am,angel1,angel2,dambi,fine1,fine2,fine3,waf,free1,free2,gbt1,gbt2,had1,had2,had3,home1,home2,home3,home4,hymn1,hymn2,hymn3,hymn4,irty1,irty2,mir1,mir2,mir3,mir4,miles1,miles2,miles3,time1,time2,time3,time4,nyn1,nyn2,nyn3,ol,ool,polo,ppcx1,ppcx2,pub1,pub2,pub3,rtla1,rtla2,rose1,rose2,rose3,sea,stay,story,wtw1,wtw2,wtw3,wal1,wal2,wal3,wau1,wau2,wreck1,wreck2,wreck3]
writefile(songlist)

# %% [markdown]
# ## Spectral features
# ### MFCC
